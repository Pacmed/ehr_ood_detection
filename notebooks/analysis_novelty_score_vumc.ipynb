# %%
import sys
import os

import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler

ROOT_PATH = '/home/karina/ehr_ood_detection/'
sys.path.append(ROOT_PATH)

from src.mappings import MAPPING_KEYS
from src.models.info import AVAILABLE_MODELS
from src.utils.datahandler import DataHandler, load_data_from_origin
from src.experiments.plot_results import load_novelty_scores_from_origin

# %%
RESULT_DIR = os.path.join(ROOT_PATH, "data/results")
PLOT_DIR = os.path.join(ROOT_PATH,"img/experiments")
STATS_DIR = os.path.join(ROOT_PATH,"data/stats")

SAVE_PATH = os.path.join(RESULT_DIR, "/VUmc/")

DATA_ORIGIN = "VUmc"

# %% [markdown]
# ### Load VUmc data

# %%
print('VUmc Dataset Summary')

for k, v in MAPPING_KEYS["VUmc"].items():
    print('\t', k, ':', v)

print('\n')
for i,j in zip([train_data, test_data, val_data], ["train samples", "test samples", "validation samples"]):
    print('\t', j, ":", len(i))

print('\n')

print('\tnumber of features total: ', train_data.shape[1])
print('\tnumber of features specified: ', len(data_loader['columns_to_use']))
print('\tnumber of features selected: ', train_data[feature_names].shape[1])
# Out:
# VUmc Dataset Summary
# 	 data_folder : /data/interim/VUmc/df_model_combined.csv
# 	 feature_names_path : /data/interim/VUmc/MLflow/columns_to_use.pkl
# 	 target_name : readmission_or_mortality_after_discharge
#
#
# 	 train samples : 12644
# 	 test samples : 2710
# 	 validation samples : 2710
#
#
# 	number of features total:  2401
# 	number of features specified:  1209
# 	number of features selected:  1196

# %%
data_loader = load_data_from_origin(DATA_ORIGIN)
dh = DataHandler(**data_loader)

# %%
feature_names = dh.load_feature_names()
y_name = dh.load_target_name()

train_data, test_data, val_data = dh.load_data_splits()

# %%
test_data[feature_names]
# Out:
#              age  alat__first__overall  alat__is_measured__first_24h  \
# 12776  66.379899                   NaN                           0.0
# 8728   35.637774                 127.0                           0.0
# 10988  81.776674                 135.0                           1.0
# 6797   62.330449                   NaN                           0.0
# 9590   39.469092                   NaN                           0.0
# ...          ...                   ...                           ...
# 17507  60.059958                  41.0                           1.0
# 587    77.577338                  31.5                           0.0
# 9346   49.508419                  18.0                           0.0
# 13269  72.316423                   NaN                           0.0
# 15941  58.686271                  20.0                           0.0
#
#        alat__is_measured__last_24h  alat__is_measured__overall  \
# 12776                          0.0                         0.0
# 8728                           0.0                         1.0
# 10988                          0.0                         1.0
# 6797                           0.0                         0.0
# 9590                           0.0                         0.0
# ...                            ...                         ...
# 17507                          0.0                         1.0
# 587                            0.0                         1.0
# 9346                           1.0                         1.0
# 13269                          0.0                         0.0
# 15941                          0.0                         1.0
#
#        alat__last__overall  alat__maximum__first_24h  alat__maximum__last_24h  \
# 12776                  NaN                       NaN                      NaN
# 8728                 115.0                       NaN                      NaN
# 10988                 58.0                     135.0                      NaN
# 6797                   NaN                       NaN                      NaN
# 9590                   NaN                       NaN                      NaN
# ...                    ...                       ...                      ...
# 17507                 41.0                      41.0                      NaN
# 587                   77.0                       NaN                      NaN
# 9346                  18.0                       NaN                     18.0
# 13269                  NaN                       NaN                      NaN
# 15941                 20.0                       NaN                      NaN
#
#        alat__maximum__overall  alat__mean__first_24h  ...  \
# 12776                     NaN                    NaN  ...
# 8728                    127.0                    NaN  ...
# 10988                   227.0                  124.0  ...
# 6797                      NaN                    NaN  ...
# 9590                      NaN                    NaN  ...
# ...                       ...                    ...  ...
# 17507                    41.0                   41.0  ...
# 587                      77.0                    NaN  ...
# 9346                     18.0                    NaN  ...
# 13269                     NaN                    NaN  ...
# 15941                    20.0                    NaN  ...
#
#        weight__mean__first_24h  weight__mean__last_24h  weight__mean__overall  \
# 12776                70.040000                     NaN              70.040000
# 8728                 90.000000                     NaN              90.000000
# 10988                70.000000                     NaN              70.000000
# 6797                109.000000                   109.0             109.000000
# 9590                 47.900000                     NaN              47.925000
# ...                        ...                     ...                    ...
# 17507               116.000000                     NaN             116.000000
# 587                        NaN                     NaN              82.000000
# 9346                 65.000000                     NaN              65.000000
# 13269                65.000000                     NaN              65.000000
# 15941                87.971429                    88.0              87.981818
#
#        weight__mean__overall__diff  weight__minimum__first_24h  \
# 12776                          NaN                        70.0
# 8728                           NaN                        90.0
# 10988                          NaN                        70.0
# 6797                      0.000000                       109.0
# 9590                           NaN                        47.7
# ...                            ...                         ...
# 17507                          NaN                       116.0
# 587                            NaN                         NaN
# 9346                           NaN                        65.0
# 13269                          NaN                        65.0
# 15941                     0.028571                        87.8
#
#        weight__minimum__last_24h  weight__minimum__overall  \
# 12776                        NaN                      70.0
# 8728                         NaN                      90.0
# 10988                        NaN                      70.0
# 6797                       109.0                     109.0
# 9590                         NaN                      47.7
# ...                          ...                       ...
# 17507                        NaN                     116.0
# 587                          NaN                      82.0
# 9346                         NaN                      65.0
# 13269                        NaN                      65.0
# 15941                       88.0                      87.8
#
#        weight__standard_deviation__first_24h  \
# 12776                               0.120000
# 8728                                0.000000
# 10988                               0.000000
# 6797                                0.000000
# 9590                                0.141421
# ...                                      ...
# 17507                               0.000000
# 587                                      NaN
# 9346                                0.000000
# 13269                               0.000000
# 15941                               0.069985
#
#        weight__standard_deviation__last_24h  \
# 12776                                   NaN
# 8728                                    NaN
# 10988                                   NaN
# 6797                                    0.0
# 9590                                    NaN
# ...                                     ...
# 17507                                   NaN
# 587                                     NaN
# 9346                                    NaN
# 13269                                   NaN
# 15941                                   0.0
#
#        weight__standard_deviation__overall
# 12776                             0.120000
# 8728                              0.000000
# 10988                             0.000000
# 6797                              0.000000
# 9590                              0.129904
# ...                                    ...
# 17507                             0.000000
# 587                               0.000000
# 9346                              0.000000
# 13269                             0.000000
# 15941                             0.057496
#
# [2710 rows x 1196 columns]

# %% [markdown]
# ### Load novelty scores for VUmc data

# %%
def export_novelty_scores():

# %%
novelty_scores, metrics = load_novelty_scores_from_origin(AVAILABLE_MODELS, RESULT_DIR, DATA_ORIGIN)

novelty_test = dict()

for key in novelty_scores.keys():
    novelty_test[key] = novelty_scores[key]['test']

# %%
# Load unscaled novelty scores
novelty_df = pd.DataFrame(novelty_test)
novelty_df.index = test_data[feature_names].index
novelty_df

# Scale scores
scaler = MinMaxScaler()
novelty_df_scaled = novelty_df.copy()
novelty_df_scaled[novelty_df_scaled.columns] = scaler.fit_transform(novelty_df_scaled)
novelty_df_scaled
# Out:
#        NN (entropy)  NN (max prob)  AE (reconstr err)  \
# 12776      0.155322       0.045246           0.010294
# 8728       0.230017       0.075065           0.019418
# 10988      0.783462       0.468480           0.041073
# 6797       0.003808       0.000583           0.004120
# 9590       0.182401       0.055544           0.021146
# ...             ...            ...                ...
# 17507      0.607400       0.299455           0.010782
# 587        0.872852       0.589186           0.014681
# 9346       0.048032       0.010748           0.016447
# 13269      0.007811       0.001309           0.003956
# 15941      0.016067       0.002984           0.007805
#
#        AnchoredNNEnsemble (entropy)  AnchoredNNEnsemble (std)  \
# 12776                      0.287624                  0.237269
# 8728                       0.485671                  0.590390
# 10988                      0.900127                  0.883044
# 6797                       0.000015                  0.000004
# 9590                       0.030985                  0.017677
# ...                             ...                       ...
# 17507                      0.892800                  0.719353
# 587                        0.920869                  0.760242
# 9346                       0.404747                  0.485312
# 13269                      0.000104                  0.000018
# 15941                      0.002642                  0.000829
#
#        AnchoredNNEnsemble (mutual information)  VAE (reconstr err)  \
# 12776                                 0.124604            0.013272
# 8728                                  0.434607            0.021545
# 10988                                 0.778372            0.022085
# 6797                                  0.000002            0.004601
# 9590                                  0.009318            0.019553
# ...                                        ...                 ...
# 17507                                 0.502438            0.015996
# 587                                   0.571016            0.015633
# 9346                                  0.337151            0.020313
# 13269                                 0.000009            0.001889
# 15941                                 0.000405            0.008786
#
#        VAE (latent prob)  VAE (latent prior prob)  VAE (reconstr err grad)  \
# 12776           0.824526                 0.042016                 0.014393
# 8728            0.790118                 0.029450                 0.005333
# 10988           0.860574                 0.056346                 0.003325
# 6797            0.787474                 0.042662                 0.063254
# 9590            0.853457                 0.025660                 0.003235
# ...                  ...                      ...                      ...
# 17507           0.814450                 0.024156                 0.006719
# 587             0.819552                 0.032486                 0.003485
# 9346            0.785406                 0.033147                 0.007202
# 13269           0.803151                 0.035606                 0.054430
# 15941           0.793300                 0.040681                 0.014688
#
#        PPCA (log prob)  NNEnsemble (entropy)  NNEnsemble (std)  \
# 12776         0.014671              0.127097          0.029934
# 8728          0.035109              0.228033          0.034041
# 10988         0.060930              0.802536          0.329291
# 6797          0.007150              0.003972          0.000361
# 9590          0.033770              0.132045          0.033596
# ...                ...                   ...               ...
# 17507         0.019765              0.763079          0.163747
# 587           0.021835              0.899374          0.186647
# 9346          0.024389              0.089776          0.015576
# 13269         0.005058              0.004687          0.000500
# 15941         0.013776              0.010817          0.001382
#
#        NNEnsemble (mutual information)  MCDropout (entropy)  MCDropout (std)  \
# 12776                         0.010313             0.170021         0.031250
# 8728                          0.006676             0.202234         0.034722
# 10988                         0.116460             0.704671         0.027778
# 6797                          0.000094             0.004823         0.000109
# 9590                          0.011495             0.183230         0.017361
# ...                                ...                  ...              ...
# 17507                         0.030917             0.759316         0.000000
# 587                           0.033159             0.917370         0.111111
# 9346                          0.004035             0.072100         0.001736
# 13269                         0.000134             0.007469         0.000326
# 15941                         0.000409             0.011856         0.000651
#
#        MCDropout (mutual information)  LOF (outlier score)
# 12776                        0.880795             0.004791
# 8728                         0.649007             0.003625
# 10988                        0.211921             0.003027
# 6797                         0.415977             0.002378
# 9590                         0.337748             0.007043
# ...                               ...                  ...
# 17507                        0.291391             0.010206
# 587                          0.397351             0.005274
# 9346                         0.132450             0.003988
# 13269                        0.760762             0.001497
# 15941                        0.185844             0.001722
#
# [2710 rows x 18 columns]

# %%
vumc_novelty_test = novelty_df.to_csv(index=True)
vumc_novelty_test_scaled = novelty_df_scaled.to_csv(index=True)

novelty_df.to_csv(r'/home/karina/ehr_ood_detection/data/results/VUmc/vumc_novelty_test.csv')
novelty_df_scaled.to_csv(r'/home/karina/ehr_ood_detection/data/results/VUmc/vumc_novelty_test_scaled.csv')

# vumc_novelty_test_scaled.to_csv(os.path.join(SAVE_PATH, 'vumc_novelty_test_scaled.csv'))
